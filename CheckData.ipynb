# %%
import uproot

# %%
# %ls BtoKmm/
# Out:
# BParkNANO_data_NewPrueba.root          crabConfig.pyc
# BParkNANO_data_NewPrueba2.root         crabConfig2.py
# BParkNANO_data_NewPrueba3.root         crabConfig2.pyc
# BParkNANO_data_NewPrueba4.root         crab_projects/
# BParkNANO_data_debug.root              events.txt
# BParkNANO_data_dubug.root              file_run.py
# BParkNANO_data_local.root              file_run.txt
# BParkNANO_data_local2.root             file_run.txt2
# BParkNANO_data_local3.root             files.txt
# BParkNANO_data_localBeamSpot.root      input.root
# BParkNANO_data_localDimuons.root       lumi_run.py
# BParkNANO_data_localKarathansis.root   out1
# BParkNANO_data_localVertexMatrix.root  pickevents.root
# config_BtoKmumu_cff.py                 run_BToKmumu_cfg.py
# config_BtoKmumu_cff.pyc                run_BToKmumu_cfg.pyc
# crab.log                               texto.txt
# crabConfig.py

# %%
file = uproot.open('BtoKmm/BParkNANO_data_localKarathansis.root')
file2 = uproot.open('BtoKmm/BParkNANO_data_localKarathansis2.root')

# %%
Events = file['Events']
Events2 = file2['Events']

# %%
Events.keys()
# Out:
# [b'run',
#  b'luminosityBlock',
#  b'event',
#  b'nPV',
#  b'PV_dzTrgMu',
#  b'PV_vx',
#  b'PV_vy',
#  b'PV_vz',
#  b'nBToKMuMu',
#  b'BToKMuMu_b_iso03',
#  b'BToKMuMu_b_iso04',
#  b'BToKMuMu_cos2D',
#  b'BToKMuMu_cosAlpha_0',
#  b'BToKMuMu_cosAlpha_1',
#  b'BToKMuMu_cosAlpha_2',
#  b'BToKMuMu_cosThetaKMu',
#  b'BToKMuMu_cosThetaMuMu',
#  b'BToKMuMu_dr_l1',
#  b'BToKMuMu_dr_l2',
#  b'BToKMuMu_dz_l1',
#  b'BToKMuMu_dz_l2',
#  b'BToKMuMu_eta',
#  b'BToKMuMu_fit_cos2D',
#  b'BToKMuMu_fit_eta',
#  b'BToKMuMu_fit_k_eta',
#  b'BToKMuMu_fit_k_phi',
#  b'BToKMuMu_fit_k_pt',
#  b'BToKMuMu_fit_l1_eta',
#  b'BToKMuMu_fit_l1_phi',
#  b'BToKMuMu_fit_l1_pt',
#  b'BToKMuMu_fit_l2_eta',
#  b'BToKMuMu_fit_l2_phi',
#  b'BToKMuMu_fit_l2_pt',
#  b'BToKMuMu_fit_mass',
#  b'BToKMuMu_fit_massErr',
#  b'BToKMuMu_fit_phi',
#  b'BToKMuMu_fit_pt',
#  b'BToKMuMu_fit_px',
#  b'BToKMuMu_fit_py',
#  b'BToKMuMu_fit_pz',
#  b'BToKMuMu_k_charge',
#  b'BToKMuMu_k_iso03',
#  b'BToKMuMu_k_iso04',
# ...

# %%
dataframe = Events.pandas.df(['Muon_isTriggering', 'BToKMuMu_l*Idx', 'BToKMuMu_significance*', 'BToKMuMu_lxy_pv*',
                             '*dz_*', '*dr_*'], 
                            flatten=False)
dataframe2 = Events2.pandas.df(['Muon_isTriggering', 'BToKMuMu_l*Idx', 'BToKMuMu_significance*', 'BToKMuMu_lxy_pv*',
                             '*dz_*', '*dr_*'], 
                            flatten=False)

# %%
dataframe
# Out:
#       Muon_isTriggering BToKMuMu_l1Idx BToKMuMu_l2Idx  \
# entry
# 0             [1, 0, 0]      [1, 1, 1]      [2, 2, 2]
# 1                [1, 0]         [0, 0]         [1, 1]
# 2             [1, 0, 0]            [1]            [2]
# 3             [1, 0, 0]            [0]            [1]
# 4                [1, 0]            [0]            [1]
# ...                 ...            ...            ...
# 123              [1, 0]            [0]            [1]
# 124        [1, 0, 0, 0]            [1]            [3]
# 125              [1, 0]            [0]            [1]
# 126           [1, 0, 0]            [1]            [2]
# 127     [1, 0, 0, 0, 0]      [2, 2, 2]      [4, 4, 4]
#
#                          BToKMuMu_significance0  \
# entry
# 0      [0.0042902436, 0.010010169, 0.020785516]
# 1                    [0.00796116, 0.0068650115]
# 2                                  [0.00778549]
# 3                                [0.0069400184]
# 4                                 [0.007107343]
# ...

# %%
dataframe2
# Out:
#       Muon_isTriggering BToKMuMu_l1Idx BToKMuMu_l2Idx  \
# entry
# 0             [1, 0, 0]      [1, 1, 1]      [2, 2, 2]
# 1                [1, 0]         [0, 0]         [1, 1]
# 2             [1, 0, 0]            [1]            [2]
# 3             [1, 0, 0]            [0]            [1]
# 4                [1, 0]            [0]            [1]
# ...                 ...            ...            ...
# 123              [1, 0]            [0]            [1]
# 124        [1, 0, 0, 0]            [1]            [3]
# 125              [1, 0]            [0]            [1]
# 126           [1, 0, 0]            [1]            [2]
# 127     [1, 0, 0, 0, 0]      [2, 2, 2]      [4, 4, 4]
#
#                      BToKMuMu_significance0  \
# entry
# 0          [2.350746, 2.0634985, 3.1410244]
# 1                    [28.118538, 31.705633]
# 2                                [1.438942]
# 3                               [61.548817]
# 4                               [6.3240542]
# ...

# %%
.010085273/.0042902436
# Out:
# 2.350746004259525
